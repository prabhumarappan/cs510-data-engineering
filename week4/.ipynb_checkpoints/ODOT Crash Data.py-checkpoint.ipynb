# %%
import pandas as pd
df = pd.read_csv('Oregon Hwy 26 Crash Data for 2019 - Crashes on Hwy 26 during 2019.csv')

# %%
# limit assertions
# asserting whether crash ID is of length 8
print(len(df))
df = df[df['Crash ID'].astype(str).str.len() == 7 ]
print(len(df))
# Out:
# 2739
# 2739

# %%
# existence assertions
for index, row in df.iterrows():
    if row['Record Type'] == 1:
        if not row['Serial #']:
            df.drop(index, inplace=True)
print(len(df))

for index, row in df.iterrows():
    if row['Record Type'] == 2:
        if not row['Vehicle ID']:
            df.drop(index, inplace=True)
print(len(df))
# Out:
# 2739
# 2739

# %%
# intra-record assertions
# For every crash id there must be a latitude and longitude
for index, row in df.iterrows():
    if row['Record Type'] == 1:
        if not row['Latitude Degrees'] and not row['Longitude Degrees']:
            df.drop(index, inplace=True)
print(len(df))

# For every participant there must be age 
for index, row in df.iterrows():
    if row['Record Type'] == 3:
        if not row['Age'] >= 0:
            print("Did not find age for record on index %d", index, row['Crash ID'], row['Age'])
            df.drop(index, inplace=True)
print(len(df))

# For every participant there must be gender 
for index, row in df.iterrows():
    if row['Record Type'] == 3:
        if not row['Sex'] in [1,2,3,9]:
            print("Did not find gender for record on index %d", index, row['Crash ID'], row['Sex'])
            df.drop(index, inplace=True)
print(len(df))
# Out:
# 2739
# Did not find age for record on index %d 8 1809229 nan
# Did not find age for record on index %d 15 1810874 nan
# Did not find age for record on index %d 60 1826673 nan
# Did not find age for record on index %d 61 1826673 nan
# Did not find age for record on index %d 62 1826673 nan
# Did not find age for record on index %d 92 1827863 nan
# Did not find age for record on index %d 272 1833867 nan
# Did not find age for record on index %d 667 1840874 nan
# Did not find age for record on index %d 668 1840874 nan
# Did not find age for record on index %d 818 1842069 nan
# Did not find age for record on index %d 819 1842069 nan
# Did not find age for record on index %d 951 1843872 nan
# Did not find age for record on index %d 1367 1847385 nan
# Did not find age for record on index %d 1827 1851072 nan
# Did not find age for record on index %d 1933 1851688 nan
# Did not find age for record on index %d 2026 1852143 nan
# Did not find age for record on index %d 2122 1852691 nan
# Did not find age for record on index %d 2162 1852889 nan
# Did not find age for record on index %d 2310 1853731 nan
# Did not find age for record on index %d 2350 1853879 nan
# 2719
# Did not find gender for record on index %d 25 1812266 4.0
# Did not find gender for record on index %d 53 1826513 4.0
# Did not find gender for record on index %d 99 1827907 4.0
# Did not find gender for record on index %d 106 1828231 4.0
# Did not find gender for record on index %d 122 1828552 4.0
# Did not find gender for record on index %d 134 1828977 4.0
# Did not find gender for record on index %d 139 1828982 4.0
# Did not find gender for record on index %d 141 1828982 4.0
# Did not find gender for record on index %d 150 1829718 4.0
# Did not find gender for record on index %d 159 1829763 4.0
# Did not find gender for record on index %d 164 1829797 4.0
# Did not find gender for record on index %d 169 1829853 4.0
# Did not find gender for record on index %d 170 1829853 4.0
# Did not find gender for record on index %d 173 1829867 4.0
# Did not find gender for record on index %d 175 1829867 4.0
# Did not find gender for record on index %d 178 1829871 4.0
# Did not find gender for record on index %d 181 1829928 4.0
# Did not find gender for record on index %d 182 1829928 4.0
# Did not find gender for record on index %d 183 1829928 4.0
# Did not find gender for record on index %d 186 1829928 4.0
# Did not find gender for record on index %d 200 1830030 4.0
# Did not find gender for record on index %d 201 1830030 4.0
# Did not find gender for record on index %d 216 1830217 4.0
# Did not find gender for record on index %d 221 1830243 4.0
# Did not find gender for record on index %d 222 1830243 4.0
# Did not find gender for record on index %d 227 1831161 4.0
# Did not find gender for record on index %d 230 1831660 4.0
# Did not find gender for record on index %d 237 1831698 4.0
# Did not find gender for record on index %d 242 1832302 4.0
# Did not find gender for record on index %d 250 1833315 4.0
# Did not find gender for record on index %d 255 1833381 4.0
# Did not find gender for record on index %d 264 1833535 4.0
# Did not find gender for record on index %d 267 1833678 4.0
# Did not find gender for record on index %d 277 1833899 4.0
# Did not find gender for record on index %d 278 1833899 4.0
# Did not find gender for record on index %d 283 1833971 4.0
# Did not find gender for record on index %d 288 1833979 4.0
# Did not find gender for record on index %d 293 1833986 4.0
# Did not find gender for record on index %d 294 1833986 4.0
# Did not find gender for record on index %d 299 1834003 4.0
# Did not find gender for record on index %d 304 1834029 4.0
# Did not find gender for record on index %d 314 1834202 4.0
# Did not find gender for record on index %d 318 1834407 4.0
# Did not find gender for record on index %d 324 1834440 4.0
# Did not find gender for record on index %d 329 1834574 4.0
# Did not find gender for record on index %d 330 1834574 4.0
# Did not find gender for record on index %d 335 1834655 4.0
# Did not find gender for record on index %d 336 1834655 4.0
# Did not find gender for record on index %d 337 1834655 4.0
# Did not find gender for record on index %d 338 1834655 4.0
# Did not find gender for record on index %d 370 1835211 4.0
# Did not find gender for record on index %d 371 1835211 4.0
# Did not find gender for record on index %d 383 1835231 4.0
# Did not find gender for record on index %d 435 1835592 4.0
# Did not find gender for record on index %d 440 1835606 4.0
# Did not find gender for record on index %d 450 1836755 4.0
# Did not find gender for record on index %d 460 1836814 4.0
# Did not find gender for record on index %d 477 1837085 4.0
# Did not find gender for record on index %d 480 1837128 4.0
# Did not find gender for record on index %d 482 1837128 4.0
# Did not find gender for record on index %d 490 1837205 4.0
# Did not find gender for record on index %d 500 1837334 4.0
# Did not find gender for record on index %d 502 1837334 4.0
# Did not find gender for record on index %d 503 1837334 4.0
# Did not find gender for record on index %d 517 1837808 4.0
# Did not find gender for record on index %d 522 1837834 4.0
# Did not find gender for record on index %d 537 1838375 4.0
# Did not find gender for record on index %d 545 1838434 4.0
# Did not find gender for record on index %d 552 1838471 4.0
# Did not find gender for record on index %d 565 1838681 4.0
# Did not find gender for record on index %d 571 1839606 4.0
# Did not find gender for record on index %d 576 1839856 4.0
# Did not find gender for record on index %d 577 1839856 4.0
# Did not find gender for record on index %d 582 1840093 4.0
# Did not find gender for record on index %d 583 1840093 4.0
# Did not find gender for record on index %d 587 1840135 4.0
# Did not find gender for record on index %d 592 1840155 4.0
# Did not find gender for record on index %d 599 1840221 4.0
# Did not find gender for record on index %d 604 1840265 4.0
# Did not find gender for record on index %d 617 1840424 4.0
# Did not find gender for record on index %d 628 1840563 4.0
# Did not find gender for record on index %d 629 1840563 4.0
# Did not find gender for record on index %d 634 1840583 4.0
# Did not find gender for record on index %d 637 1840588 4.0
# Did not find gender for record on index %d 638 1840588 4.0
# Did not find gender for record on index %d 650 1840614 4.0
# Did not find gender for record on index %d 655 1840664 4.0
# Did not find gender for record on index %d 661 1840832 4.0
# Did not find gender for record on index %d 673 1840905 4.0
# Did not find gender for record on index %d 678 1841009 4.0
# Did not find gender for record on index %d 679 1841009 4.0
# Did not find gender for record on index %d 680 1841009 4.0
# Did not find gender for record on index %d 681 1841009 4.0
# Did not find gender for record on index %d 686 1841013 4.0
# Did not find gender for record on index %d 691 1841019 4.0
# Did not find gender for record on index %d 700 1841151 4.0
# Did not find gender for record on index %d 704 1841157 4.0
# Did not find gender for record on index %d 715 1841331 4.0
# Did not find gender for record on index %d 716 1841331 4.0
# Did not find gender for record on index %d 719 1841336 4.0
# Did not find gender for record on index %d 721 1841336 4.0
# Did not find gender for record on index %d 725 1841343 4.0
# Did not find gender for record on index %d 726 1841343 4.0
# Did not find gender for record on index %d 727 1841343 4.0
# Did not find gender for record on index %d 729 1841343 4.0
# Did not find gender for record on index %d 730 1841343 4.0
# Did not find gender for record on index %d 735 1841361 4.0
# Did not find gender for record on index %d 739 1841369 4.0
# Did not find gender for record on index %d 741 1841369 4.0
# Did not find gender for record on index %d 742 1841369 4.0
# Did not find gender for record on index %d 754 1841436 4.0
# Did not find gender for record on index %d 759 1841498 4.0
# Did not find gender for record on index %d 767 1841641 4.0
# Did not find gender for record on index %d 773 1841685 4.0
# Did not find gender for record on index %d 774 1841685 4.0
# Did not find gender for record on index %d 779 1841691 4.0
# Did not find gender for record on index %d 784 1841693 4.0
# Did not find gender for record on index %d 785 1841693 4.0
# Did not find gender for record on index %d 790 1841708 4.0
# Did not find gender for record on index %d 801 1841766 4.0
# Did not find gender for record on index %d 811 1841855 4.0
# Did not find gender for record on index %d 824 1842180 4.0
# Did not find gender for record on index %d 831 1842244 4.0
# Did not find gender for record on index %d 836 1842388 4.0
# Did not find gender for record on index %d 841 1842703 4.0
# Did not find gender for record on index %d 843 1842703 4.0
# Did not find gender for record on index %d 844 1842703 4.0
# Did not find gender for record on index %d 853 1842822 4.0
# Did not find gender for record on index %d 859 1842862 4.0
# Did not find gender for record on index %d 861 1842862 4.0
# Did not find gender for record on index %d 862 1842862 4.0
# Did not find gender for record on index %d 865 1843136 4.0
# Did not find gender for record on index %d 872 1843196 4.0
# Did not find gender for record on index %d 876 1843399 4.0
# Did not find gender for record on index %d 883 1843400 4.0
# Did not find gender for record on index %d 884 1843400 4.0
# Did not find gender for record on index %d 886 1843400 4.0
# Did not find gender for record on index %d 891 1843445 4.0
# Did not find gender for record on index %d 892 1843445 4.0
# Did not find gender for record on index %d 897 1843562 4.0
# Did not find gender for record on index %d 904 1843658 4.0
# Did not find gender for record on index %d 909 1843709 4.0
# Did not find gender for record on index %d 915 1843746 4.0
# Did not find gender for record on index %d 920 1843752 4.0
# Did not find gender for record on index %d 921 1843752 4.0
# Did not find gender for record on index %d 933 1843796 4.0
# Did not find gender for record on index %d 935 1843796 4.0
# Did not find gender for record on index %d 939 1843814 4.0
# Did not find gender for record on index %d 944 1843842 4.0
# Did not find gender for record on index %d 945 1843842 4.0
# Did not find gender for record on index %d 946 1843842 4.0
# Did not find gender for record on index %d 954 1843940 4.0
# Did not find gender for record on index %d 955 1843940 4.0
# Did not find gender for record on index %d 962 1843953 4.0
# Did not find gender for record on index %d 963 1843953 4.0
# Did not find gender for record on index %d 964 1843953 4.0
# Did not find gender for record on index %d 965 1843953 4.0
# Did not find gender for record on index %d 972 1844151 4.0
# Did not find gender for record on index %d 977 1844301 4.0
# Did not find gender for record on index %d 982 1844339 4.0
# Did not find gender for record on index %d 987 1844458 4.0
# Did not find gender for record on index %d 988 1844458 4.0
# Did not find gender for record on index %d 989 1844458 4.0
# Did not find gender for record on index %d 994 1844484 4.0
# Did not find gender for record on index %d 999 1844488 4.0
# Did not find gender for record on index %d 1000 1844488 4.0
# Did not find gender for record on index %d 1005 1844762 4.0
# Did not find gender for record on index %d 1008 1844762 4.0
# Did not find gender for record on index %d 1013 1844813 4.0
# Did not find gender for record on index %d 1018 1844857 4.0
# Did not find gender for record on index %d 1019 1844857 4.0
# Did not find gender for record on index %d 1021 1844857 4.0
# Did not find gender for record on index %d 1022 1844857 4.0
# Did not find gender for record on index %d 1025 1844942 4.0
# Did not find gender for record on index %d 1026 1844942 4.0
# Did not find gender for record on index %d 1030 1844976 4.0
# Did not find gender for record on index %d 1032 1844976 4.0
# Did not find gender for record on index %d 1037 1845024 4.0
# Did not find gender for record on index %d 1042 1845085 4.0
# Did not find gender for record on index %d 1044 1845085 4.0
# Did not find gender for record on index %d 1049 1845101 4.0
# Did not find gender for record on index %d 1052 1845113 4.0
# Did not find gender for record on index %d 1058 1845254 4.0
# Did not find gender for record on index %d 1065 1845255 4.0
# Did not find gender for record on index %d 1070 1845302 4.0
# Did not find gender for record on index %d 1077 1845326 4.0
# Did not find gender for record on index %d 1078 1845326 4.0
# Did not find gender for record on index %d 1083 1845378 4.0
# Did not find gender for record on index %d 1088 1845474 4.0
# Did not find gender for record on index %d 1092 1845603 4.0
# Did not find gender for record on index %d 1094 1845603 4.0
# Did not find gender for record on index %d 1095 1845603 4.0
# Did not find gender for record on index %d 1096 1845603 4.0
# Did not find gender for record on index %d 1106 1845672 4.0
# Did not find gender for record on index %d 1114 1845755 4.0
# Did not find gender for record on index %d 1116 1845755 4.0
# Did not find gender for record on index %d 1121 1845835 4.0
# Did not find gender for record on index %d 1126 1845949 4.0
# Did not find gender for record on index %d 1131 1845964 4.0
# Did not find gender for record on index %d 1136 1845971 4.0
# Did not find gender for record on index %d 1137 1845971 4.0
# Did not find gender for record on index %d 1141 1845975 4.0
# Did not find gender for record on index %d 1146 1845982 4.0
# Did not find gender for record on index %d 1147 1845982 4.0
# Did not find gender for record on index %d 1156 1846015 4.0
# Did not find gender for record on index %d 1161 1846016 4.0
# Did not find gender for record on index %d 1162 1846016 4.0
# Did not find gender for record on index %d 1167 1846021 4.0
# Did not find gender for record on index %d 1170 1846139 4.0
# Did not find gender for record on index %d 1177 1846145 4.0
# Did not find gender for record on index %d 1182 1846158 4.0
# Did not find gender for record on index %d 1192 1846303 4.0
# Did not find gender for record on index %d 1193 1846303 4.0
# Did not find gender for record on index %d 1198 1846318 4.0
# Did not find gender for record on index %d 1203 1846364 4.0
# Did not find gender for record on index %d 1204 1846364 4.0
# Did not find gender for record on index %d 1205 1846364 4.0
# Did not find gender for record on index %d 1206 1846364 4.0
# Did not find gender for record on index %d 1213 1846373 4.0
# Did not find gender for record on index %d 1218 1846424 4.0
# Did not find gender for record on index %d 1223 1846442 4.0
# Did not find gender for record on index %d 1228 1846452 4.0
# Did not find gender for record on index %d 1239 1846575 4.0
# Did not find gender for record on index %d 1246 1846641 4.0
# Did not find gender for record on index %d 1254 1846707 4.0
# Did not find gender for record on index %d 1256 1846707 4.0
# Did not find gender for record on index %d 1259 1846797 4.0
# Did not find gender for record on index %d 1264 1846812 4.0
# Did not find gender for record on index %d 1273 1846840 4.0
# Did not find gender for record on index %d 1278 1846965 4.0
# Did not find gender for record on index %d 1283 1847023 4.0
# Did not find gender for record on index %d 1286 1847026 4.0
# Did not find gender for record on index %d 1293 1847080 4.0
# Did not find gender for record on index %d 1298 1847084 4.0
# Did not find gender for record on index %d 1299 1847084 4.0
# Did not find gender for record on index %d 1304 1847184 4.0
# Did not find gender for record on index %d 1309 1847234 4.0
# Did not find gender for record on index %d 1310 1847234 4.0
# Did not find gender for record on index %d 1317 1847302 4.0
# Did not find gender for record on index %d 1328 1847313 4.0
# Did not find gender for record on index %d 1333 1847332 4.0
# Did not find gender for record on index %d 1339 1847352 4.0
# Did not find gender for record on index %d 1344 1847358 4.0
# Did not find gender for record on index %d 1351 1847366 4.0
# Did not find gender for record on index %d 1356 1847371 4.0
# Did not find gender for record on index %d 1358 1847371 4.0
# Did not find gender for record on index %d 1363 1847378 4.0
# Did not find gender for record on index %d 1373 1847491 4.0
# Did not find gender for record on index %d 1375 1847491 4.0
# Did not find gender for record on index %d 1376 1847491 4.0
# Did not find gender for record on index %d 1377 1847491 4.0
# Did not find gender for record on index %d 1384 1847500 4.0
# Did not find gender for record on index %d 1387 1847540 4.0
# Did not find gender for record on index %d 1389 1847540 4.0
# Did not find gender for record on index %d 1390 1847540 4.0
# Did not find gender for record on index %d 1399 1847575 4.0
# Did not find gender for record on index %d 1401 1847575 4.0
# Did not find gender for record on index %d 1402 1847575 4.0
# Did not find gender for record on index %d 1407 1847667 4.0
# Did not find gender for record on index %d 1410 1847722 4.0
# Did not find gender for record on index %d 1412 1847722 4.0
# Did not find gender for record on index %d 1413 1847722 4.0
# Did not find gender for record on index %d 1414 1847722 4.0
# Did not find gender for record on index %d 1419 1847889 4.0
# Did not find gender for record on index %d 1422 1847898 4.0
# Did not find gender for record on index %d 1432 1847900 4.0
# Did not find gender for record on index %d 1437 1847935 4.0
# Did not find gender for record on index %d 1444 1847949 4.0
# Did not find gender for record on index %d 1449 1847958 4.0
# Did not find gender for record on index %d 1456 1848047 4.0
# Did not find gender for record on index %d 1461 1848054 4.0
# Did not find gender for record on index %d 1466 1848083 4.0
# Did not find gender for record on index %d 1469 1848156 4.0
# Did not find gender for record on index %d 1471 1848156 4.0
# Did not find gender for record on index %d 1478 1848222 4.0
# Did not find gender for record on index %d 1483 1848270 4.0
# Did not find gender for record on index %d 1484 1848270 4.0
# Did not find gender for record on index %d 1489 1848337 4.0
# Did not find gender for record on index %d 1501 1848359 4.0
# Did not find gender for record on index %d 1504 1848489 4.0
# Did not find gender for record on index %d 1511 1848512 4.0
# Did not find gender for record on index %d 1516 1848553 4.0
# Did not find gender for record on index %d 1521 1848565 4.0
# Did not find gender for record on index %d 1526 1848616 4.0
# Did not find gender for record on index %d 1536 1848792 4.0
# Did not find gender for record on index %d 1542 1848895 4.0
# Did not find gender for record on index %d 1549 1848913 4.0
# Did not find gender for record on index %d 1554 1849019 4.0
# Did not find gender for record on index %d 1556 1849019 4.0
# Did not find gender for record on index %d 1563 1849023 4.0
# Did not find gender for record on index %d 1570 1849220 4.0
# Did not find gender for record on index %d 1576 1849271 4.0
# Did not find gender for record on index %d 1584 1849286 4.0
# Did not find gender for record on index %d 1590 1849289 4.0
# Did not find gender for record on index %d 1595 1849323 4.0
# Did not find gender for record on index %d 1600 1849337 4.0
# Did not find gender for record on index %d 1601 1849337 4.0
# Did not find gender for record on index %d 1606 1849386 4.0
# Did not find gender for record on index %d 1607 1849386 4.0
# Did not find gender for record on index %d 1614 1849472 4.0
# Did not find gender for record on index %d 1619 1849480 4.0
# Did not find gender for record on index %d 1624 1849501 4.0
# Did not find gender for record on index %d 1625 1849501 4.0
# Did not find gender for record on index %d 1626 1849501 4.0
# Did not find gender for record on index %d 1627 1849501 4.0
# Did not find gender for record on index %d 1633 1849503 4.0
# Did not find gender for record on index %d 1638 1849552 4.0
# Did not find gender for record on index %d 1643 1849597 4.0
# Did not find gender for record on index %d 1644 1849597 4.0
# Did not find gender for record on index %d 1645 1849597 4.0
# Did not find gender for record on index %d 1650 1849637 4.0
# Did not find gender for record on index %d 1655 1849683 4.0
# Did not find gender for record on index %d 1660 1849777 4.0
# Did not find gender for record on index %d 1661 1849777 4.0
# Did not find gender for record on index %d 1667 1849815 4.0
# Did not find gender for record on index %d 1675 1849893 4.0
# Did not find gender for record on index %d 1676 1849893 4.0
# Did not find gender for record on index %d 1681 1849940 4.0
# Did not find gender for record on index %d 1689 1850002 4.0
# Did not find gender for record on index %d 1692 1850038 4.0
# Did not find gender for record on index %d 1699 1850223 4.0
# Did not find gender for record on index %d 1706 1850230 4.0
# Did not find gender for record on index %d 1707 1850230 4.0
# Did not find gender for record on index %d 1710 1850352 4.0
# Did not find gender for record on index %d 1711 1850352 4.0
# Did not find gender for record on index %d 1716 1850368 4.0
# Did not find gender for record on index %d 1723 1850651 4.0
# Did not find gender for record on index %d 1726 1850653 4.0
# Did not find gender for record on index %d 1733 1850737 4.0
# Did not find gender for record on index %d 1734 1850737 4.0
# Did not find gender for record on index %d 1735 1850737 4.0
# Did not find gender for record on index %d 1736 1850737 4.0
# Did not find gender for record on index %d 1741 1850744 4.0
# Did not find gender for record on index %d 1744 1850772 4.0
# Did not find gender for record on index %d 1756 1850810 4.0
# Did not find gender for record on index %d 1759 1850874 4.0
# Did not find gender for record on index %d 1764 1850879 4.0
# Did not find gender for record on index %d 1766 1850879 4.0
# Did not find gender for record on index %d 1767 1850879 4.0
# Did not find gender for record on index %d 1774 1850898 4.0
# Did not find gender for record on index %d 1780 1850911 4.0
# Did not find gender for record on index %d 1785 1850939 4.0
# Did not find gender for record on index %d 1787 1850939 4.0
# Did not find gender for record on index %d 1791 1850968 4.0
# Did not find gender for record on index %d 1795 1850968 4.0
# Did not find gender for record on index %d 1800 1850983 4.0
# Did not find gender for record on index %d 1801 1850983 4.0
# Did not find gender for record on index %d 1806 1851014 4.0
# Did not find gender for record on index %d 1807 1851014 4.0
# Did not find gender for record on index %d 1808 1851014 4.0
# Did not find gender for record on index %d 1813 1851035 4.0
# Did not find gender for record on index %d 1818 1851041 4.0
# Did not find gender for record on index %d 1823 1851062 4.0
# Did not find gender for record on index %d 1837 1851097 4.0
# Did not find gender for record on index %d 1838 1851097 4.0
# Did not find gender for record on index %d 1841 1851131 4.0
# Did not find gender for record on index %d 1848 1851142 4.0
# Did not find gender for record on index %d 1853 1851178 4.0
# Did not find gender for record on index %d 1854 1851178 4.0
# Did not find gender for record on index %d 1859 1851189 4.0
# Did not find gender for record on index %d 1865 1851193 4.0
# Did not find gender for record on index %d 1873 1851272 4.0
# Did not find gender for record on index %d 1878 1851274 4.0
# Did not find gender for record on index %d 1881 1851313 4.0
# Did not find gender for record on index %d 1889 1851526 4.0
# Did not find gender for record on index %d 1894 1851540 4.0
# Did not find gender for record on index %d 1895 1851540 4.0
# Did not find gender for record on index %d 1900 1851552 4.0
# Did not find gender for record on index %d 1905 1851557 4.0
# Did not find gender for record on index %d 1910 1851558 4.0
# Did not find gender for record on index %d 1913 1851558 4.0
# Did not find gender for record on index %d 1918 1851564 4.0
# Did not find gender for record on index %d 1928 1851609 4.0
# Did not find gender for record on index %d 1936 1851693 4.0
# Did not find gender for record on index %d 1941 1851700 4.0
# Did not find gender for record on index %d 1944 1851706 4.0
# Did not find gender for record on index %d 1945 1851706 4.0
# Did not find gender for record on index %d 1946 1851706 4.0
# Did not find gender for record on index %d 1947 1851706 4.0
# Did not find gender for record on index %d 1952 1851721 4.0
# Did not find gender for record on index %d 1953 1851721 4.0
# Did not find gender for record on index %d 1961 1851723 4.0
# Did not find gender for record on index %d 1966 1851759 4.0
# Did not find gender for record on index %d 1971 1851776 4.0
# Did not find gender for record on index %d 1972 1851776 4.0
# Did not find gender for record on index %d 1974 1851776 4.0
# Did not find gender for record on index %d 1977 1851837 4.0
# Did not find gender for record on index %d 1982 1851849 4.0
# Did not find gender for record on index %d 1994 1851959 4.0
# Did not find gender for record on index %d 1999 1851966 4.0
# Did not find gender for record on index %d 2004 1852005 4.0
# Did not find gender for record on index %d 2011 1852048 4.0
# Did not find gender for record on index %d 2012 1852048 4.0
# Did not find gender for record on index %d 2017 1852070 4.0
# Did not find gender for record on index %d 2022 1852116 4.0
# Did not find gender for record on index %d 2036 1852201 4.0
# Did not find gender for record on index %d 2039 1852212 4.0
# Did not find gender for record on index %d 2045 1852223 4.0
# Did not find gender for record on index %d 2050 1852287 4.0
# Did not find gender for record on index %d 2060 1852369 4.0
# Did not find gender for record on index %d 2072 1852381 4.0
# Did not find gender for record on index %d 2080 1852385 4.0
# Did not find gender for record on index %d 2085 1852404 4.0
# Did not find gender for record on index %d 2087 1852404 4.0
# Did not find gender for record on index %d 2090 1852464 4.0
# Did not find gender for record on index %d 2098 1852483 4.0
# Did not find gender for record on index %d 2099 1852483 4.0
# Did not find gender for record on index %d 2100 1852483 4.0
# Did not find gender for record on index %d 2105 1852562 4.0
# Did not find gender for record on index %d 2107 1852562 4.0
# Did not find gender for record on index %d 2112 1852623 4.0
# Did not find gender for record on index %d 2113 1852623 4.0
# Did not find gender for record on index %d 2118 1852657 4.0
# Did not find gender for record on index %d 2127 1852735 4.0
# Did not find gender for record on index %d 2138 1852773 4.0
# Did not find gender for record on index %d 2143 1852807 4.0
# Did not find gender for record on index %d 2152 1852853 4.0
# Did not find gender for record on index %d 2156 1852870 4.0
# Did not find gender for record on index %d 2167 1852933 4.0
# Did not find gender for record on index %d 2168 1852933 4.0
# Did not find gender for record on index %d 2173 1852934 4.0
# Did not find gender for record on index %d 2174 1852934 4.0
# Did not find gender for record on index %d 2179 1852937 4.0
# Did not find gender for record on index %d 2180 1852937 4.0
# Did not find gender for record on index %d 2185 1852965 4.0
# Did not find gender for record on index %d 2190 1852981 4.0
# Did not find gender for record on index %d 2195 1853011 4.0
# Did not find gender for record on index %d 2200 1853019 4.0
# Did not find gender for record on index %d 2201 1853019 4.0
# Did not find gender for record on index %d 2202 1853019 4.0
# Did not find gender for record on index %d 2206 1853209 4.0
# Did not find gender for record on index %d 2211 1853242 4.0
# Did not find gender for record on index %d 2213 1853242 4.0
# Did not find gender for record on index %d 2214 1853242 4.0
# Did not find gender for record on index %d 2219 1853265 4.0
# Did not find gender for record on index %d 2220 1853265 4.0
# Did not find gender for record on index %d 2227 1853304 4.0
# Did not find gender for record on index %d 2228 1853304 4.0
# Did not find gender for record on index %d 2233 1853339 4.0
# Did not find gender for record on index %d 2234 1853339 4.0
# Did not find gender for record on index %d 2239 1853353 4.0
# Did not find gender for record on index %d 2244 1853448 4.0
# Did not find gender for record on index %d 2249 1853466 4.0
# Did not find gender for record on index %d 2250 1853466 4.0
# Did not find gender for record on index %d 2251 1853466 4.0
# Did not find gender for record on index %d 2254 1853499 4.0
# Did not find gender for record on index %d 2261 1853505 4.0
# Did not find gender for record on index %d 2271 1853517 4.0
# Did not find gender for record on index %d 2274 1853519 4.0
# Did not find gender for record on index %d 2277 1853543 4.0
# Did not find gender for record on index %d 2282 1853582 4.0
# Did not find gender for record on index %d 2284 1853582 4.0
# Did not find gender for record on index %d 2297 1853699 4.0
# Did not find gender for record on index %d 2302 1853728 4.0
# Did not find gender for record on index %d 2305 1853728 4.0
# Did not find gender for record on index %d 2306 1853728 4.0
# Did not find gender for record on index %d 2313 1853788 4.0
# Did not find gender for record on index %d 2320 1853809 4.0
# Did not find gender for record on index %d 2336 1853862 4.0
# Did not find gender for record on index %d 2337 1853862 4.0
# Did not find gender for record on index %d 2344 1853863 4.0
# Did not find gender for record on index %d 2345 1853863 4.0
# Did not find gender for record on index %d 2346 1853863 4.0
# Did not find gender for record on index %d 2358 1853898 4.0
# Did not find gender for record on index %d 2365 1853962 4.0
# Did not find gender for record on index %d 2368 1853962 4.0
# Did not find gender for record on index %d 2371 1854007 4.0
# Did not find gender for record on index %d 2375 1854007 4.0
# Did not find gender for record on index %d 2380 1854013 4.0
# Did not find gender for record on index %d 2383 1854063 4.0
# Did not find gender for record on index %d 2390 1854066 4.0
# Did not find gender for record on index %d 2395 1854071 4.0
# Did not find gender for record on index %d 2400 1854092 4.0
# Did not find gender for record on index %d 2405 1854099 4.0
# Did not find gender for record on index %d 2410 1854169 4.0
# Did not find gender for record on index %d 2415 1854273 4.0
# Did not find gender for record on index %d 2424 1854309 4.0
# Did not find gender for record on index %d 2436 1854338 4.0
# Did not find gender for record on index %d 2443 1854339 4.0
# Did not find gender for record on index %d 2444 1854339 4.0
# Did not find gender for record on index %d 2454 1854392 4.0
# Did not find gender for record on index %d 2459 1854398 4.0
# Did not find gender for record on index %d 2528 1855657 4.0
# 2236

# %%
# inter-record assertions
# For every crashId there will be atleast one vehicle id
for index, row in df.iterrows():
    if row['Record Type'] == 2:
        if not row['Vehicle ID']:
            print("Did not find vehicle Id for the record on index ", index, row['Crash ID'])
            df.drop(index, inplace=True)
print(len(df))

# For every crashId, there will be atleast 2 types of records
record_dict = {}
for index, row in df.iterrows():
    crash_id = row['Crash ID']
    str_crash_id = str(crash_id)
    record_type = row['Record Type']
    if str_crash_id not in record_dict:
        record_dict[str_crash_id] = []
    if record_type == 1:
        key = '%s-%s' % (crash_id, record_type)
        if key not in record_dict[str_crash_id]:
            record_dict[str_crash_id].append(key)
        else:
            print("duplicated key ", key)
    elif record_type == 2:
        vehicle_id = row['Vehicle ID']
        key = '%s-%s' % (crash_id, vehicle_id)
        if key not in record_dict[str_crash_id]:
            record_dict[str_crash_id].append(key)
        else:
            print("duplicated key ", key)
    elif record_type == 3:
        participant_id = row['Participant ID']
        key = '%s-%s' % (crash_id, participant_id)
        if key not in record_dict[str_crash_id]:
            record_dict[str_crash_id].append(key)
        else:
            print("duplicated key ", key)
# Out:
# 2739

# %%
# summary assertions
# CrashId is unique across all the records
crash_id = set()
print(len(df))
for index, row in df.iterrows():
    if row['Record Type'] == 1:
        if row['Crash ID'] in crash_id:
            print("Crash ID is repeated ", index, row['Crash ID'])
            df.drop(index, inplace=True)
        else:
            crash_id.add(row['Crash ID'])
print(len(df))

# For every crash, the number of participants should be more than or equal to the number of cars
crash_stats = {}
for index, row in df.iterrows():
    crash_id = row['Crash ID']
    if str_crash_id not in crash_stats:
        crash_stats[str_crash_id] = {
            'p':0,
            'v':0
        }
    str_crash_id = str(crash_id)
    if row['Record Type'] == 2:
        crash_stats[str_crash_id]['v'] += 1
    if row['Record Type'] == 3:
        crash_stats[str_crash_id]['p'] += 1

wrong_counter = 0
for crash_id in crash_stats:
    crash_v = crash_stats[crash_id]['v']
    crash_p = crash_stats[crash_id]['p']
    if crash_v > crash_p:
        print("More vehicles than participants for crash ", crash_id)
        wrong_counter += 1
# Out:
# 2236
# 2236
# More vehicles than participants for crash  1827872
# More vehicles than participants for crash  1827907
# More vehicles than participants for crash  1828231
# More vehicles than participants for crash  1828552
# More vehicles than participants for crash  1828977
# More vehicles than participants for crash  1828982
# More vehicles than participants for crash  1829718
# More vehicles than participants for crash  1829797
# More vehicles than participants for crash  1829853
# More vehicles than participants for crash  1829867
# More vehicles than participants for crash  1829871
# More vehicles than participants for crash  1830217
# More vehicles than participants for crash  1830243
# More vehicles than participants for crash  1831161
# More vehicles than participants for crash  1831660
# More vehicles than participants for crash  1831698
# More vehicles than participants for crash  1832302
# More vehicles than participants for crash  1833315
# More vehicles than participants for crash  1833381
# More vehicles than participants for crash  1833535
# More vehicles than participants for crash  1833678
# More vehicles than participants for crash  1833899
# More vehicles than participants for crash  1833971
# More vehicles than participants for crash  1833979
# More vehicles than participants for crash  1833986
# More vehicles than participants for crash  1834003
# More vehicles than participants for crash  1834029
# More vehicles than participants for crash  1834202
# More vehicles than participants for crash  1834574
# More vehicles than participants for crash  1834655
# More vehicles than participants for crash  1835211
# More vehicles than participants for crash  1835592
# More vehicles than participants for crash  1835606
# More vehicles than participants for crash  1836755
# More vehicles than participants for crash  1836814
# More vehicles than participants for crash  1837128
# More vehicles than participants for crash  1837205
# More vehicles than participants for crash  1837334
# More vehicles than participants for crash  1837808
# More vehicles than participants for crash  1837834
# More vehicles than participants for crash  1838375
# More vehicles than participants for crash  1838434
# More vehicles than participants for crash  1838471
# More vehicles than participants for crash  1838681
# More vehicles than participants for crash  1839856
# More vehicles than participants for crash  1840093
# More vehicles than participants for crash  1840155
# More vehicles than participants for crash  1840221
# More vehicles than participants for crash  1840265
# More vehicles than participants for crash  1840424
# More vehicles than participants for crash  1840563
# More vehicles than participants for crash  1840583
# More vehicles than participants for crash  1840588
# More vehicles than participants for crash  1840614
# More vehicles than participants for crash  1840664
# More vehicles than participants for crash  1840832
# More vehicles than participants for crash  1840905
# More vehicles than participants for crash  1841009
# More vehicles than participants for crash  1841013
# More vehicles than participants for crash  1841019
# More vehicles than participants for crash  1841151
# More vehicles than participants for crash  1841331
# More vehicles than participants for crash  1841336
# More vehicles than participants for crash  1841343
# More vehicles than participants for crash  1841361
# More vehicles than participants for crash  1841369
# More vehicles than participants for crash  1841436
# More vehicles than participants for crash  1841498
# More vehicles than participants for crash  1841685
# More vehicles than participants for crash  1841691
# More vehicles than participants for crash  1841693
# More vehicles than participants for crash  1841708
# More vehicles than participants for crash  1841766
# More vehicles than participants for crash  1841855
# More vehicles than participants for crash  1842180
# More vehicles than participants for crash  1842244
# More vehicles than participants for crash  1842388
# More vehicles than participants for crash  1842703
# More vehicles than participants for crash  1842822
# More vehicles than participants for crash  1842862
# More vehicles than participants for crash  1843136
# More vehicles than participants for crash  1843399
# More vehicles than participants for crash  1843400
# More vehicles than participants for crash  1843445
# More vehicles than participants for crash  1843562
# More vehicles than participants for crash  1843658
# More vehicles than participants for crash  1843709
# More vehicles than participants for crash  1843752
# More vehicles than participants for crash  1843796
# More vehicles than participants for crash  1843842
# More vehicles than participants for crash  1843872
# More vehicles than participants for crash  1843940
# More vehicles than participants for crash  1843953
# More vehicles than participants for crash  1844151
# More vehicles than participants for crash  1844301
# More vehicles than participants for crash  1844339
# More vehicles than participants for crash  1844458
# More vehicles than participants for crash  1844484
# More vehicles than participants for crash  1844488
# More vehicles than participants for crash  1844762
# More vehicles than participants for crash  1844813
# More vehicles than participants for crash  1844857
# More vehicles than participants for crash  1844976
# More vehicles than participants for crash  1845024
# More vehicles than participants for crash  1845085
# More vehicles than participants for crash  1845101
# More vehicles than participants for crash  1845113
# More vehicles than participants for crash  1845255
# More vehicles than participants for crash  1845302
# More vehicles than participants for crash  1845326
# More vehicles than participants for crash  1845378
# More vehicles than participants for crash  1845474
# More vehicles than participants for crash  1845603
# More vehicles than participants for crash  1845672
# More vehicles than participants for crash  1845755
# More vehicles than participants for crash  1845835
# More vehicles than participants for crash  1845949
# More vehicles than participants for crash  1845964
# More vehicles than participants for crash  1845971
# More vehicles than participants for crash  1845982
# More vehicles than participants for crash  1846015
# More vehicles than participants for crash  1846016
# More vehicles than participants for crash  1846021
# More vehicles than participants for crash  1846139
# More vehicles than participants for crash  1846145
# More vehicles than participants for crash  1846158
# More vehicles than participants for crash  1846303
# More vehicles than participants for crash  1846318
# More vehicles than participants for crash  1846364
# More vehicles than participants for crash  1846373
# More vehicles than participants for crash  1846424
# More vehicles than participants for crash  1846442
# More vehicles than participants for crash  1846452
# More vehicles than participants for crash  1846543
# More vehicles than participants for crash  1846641
# More vehicles than participants for crash  1846707
# More vehicles than participants for crash  1846797
# More vehicles than participants for crash  1846812
# More vehicles than participants for crash  1846840
# More vehicles than participants for crash  1846965
# More vehicles than participants for crash  1847023
# More vehicles than participants for crash  1847026
# More vehicles than participants for crash  1847080
# More vehicles than participants for crash  1847084
# More vehicles than participants for crash  1847184
# More vehicles than participants for crash  1847234
# More vehicles than participants for crash  1847302
# More vehicles than participants for crash  1847313
# More vehicles than participants for crash  1847332
# More vehicles than participants for crash  1847358
# More vehicles than participants for crash  1847366
# More vehicles than participants for crash  1847371
# More vehicles than participants for crash  1847378
# More vehicles than participants for crash  1847491
# More vehicles than participants for crash  1847500
# More vehicles than participants for crash  1847540
# More vehicles than participants for crash  1847575
# More vehicles than participants for crash  1847667
# More vehicles than participants for crash  1847722
# More vehicles than participants for crash  1847889
# More vehicles than participants for crash  1847900
# More vehicles than participants for crash  1847935
# More vehicles than participants for crash  1847949
# More vehicles than participants for crash  1847958
# More vehicles than participants for crash  1848047
# More vehicles than participants for crash  1848054
# More vehicles than participants for crash  1848083
# More vehicles than participants for crash  1848156
# More vehicles than participants for crash  1848222
# More vehicles than participants for crash  1848270
# More vehicles than participants for crash  1848337
# More vehicles than participants for crash  1848359
# More vehicles than participants for crash  1848489
# More vehicles than participants for crash  1848512
# More vehicles than participants for crash  1848553
# More vehicles than participants for crash  1848565
# More vehicles than participants for crash  1848616
# More vehicles than participants for crash  1848792
# More vehicles than participants for crash  1848913
# More vehicles than participants for crash  1849019
# More vehicles than participants for crash  1849023
# More vehicles than participants for crash  1849220
# More vehicles than participants for crash  1849289
# More vehicles than participants for crash  1849323
# More vehicles than participants for crash  1849337
# More vehicles than participants for crash  1849386
# More vehicles than participants for crash  1849472
# More vehicles than participants for crash  1849480
# More vehicles than participants for crash  1849501
# More vehicles than participants for crash  1849552
# More vehicles than participants for crash  1849597
# More vehicles than participants for crash  1849637
# More vehicles than participants for crash  1849683
# More vehicles than participants for crash  1849777
# More vehicles than participants for crash  1849940
# More vehicles than participants for crash  1850002
# More vehicles than participants for crash  1850038
# More vehicles than participants for crash  1850223
# More vehicles than participants for crash  1850230
# More vehicles than participants for crash  1850352
# More vehicles than participants for crash  1850368
# More vehicles than participants for crash  1850651
# More vehicles than participants for crash  1850653
# More vehicles than participants for crash  1850737
# More vehicles than participants for crash  1850744
# More vehicles than participants for crash  1850772
# More vehicles than participants for crash  1850810
# More vehicles than participants for crash  1850874
# More vehicles than participants for crash  1850879
# More vehicles than participants for crash  1850898
# More vehicles than participants for crash  1850911
# More vehicles than participants for crash  1850939
# More vehicles than participants for crash  1850968
# More vehicles than participants for crash  1850983
# More vehicles than participants for crash  1851014
# More vehicles than participants for crash  1851035
# More vehicles than participants for crash  1851041
# More vehicles than participants for crash  1851062
# More vehicles than participants for crash  1851097
# More vehicles than participants for crash  1851131
# More vehicles than participants for crash  1851142
# More vehicles than participants for crash  1851178
# More vehicles than participants for crash  1851189
# More vehicles than participants for crash  1851272
# More vehicles than participants for crash  1851274
# More vehicles than participants for crash  1851313
# More vehicles than participants for crash  1851526
# More vehicles than participants for crash  1851540
# More vehicles than participants for crash  1851552
# More vehicles than participants for crash  1851557
# More vehicles than participants for crash  1851558
# More vehicles than participants for crash  1851564
# More vehicles than participants for crash  1851609
# More vehicles than participants for crash  1851693
# More vehicles than participants for crash  1851700
# More vehicles than participants for crash  1851706
# More vehicles than participants for crash  1851721
# More vehicles than participants for crash  1851759
# More vehicles than participants for crash  1851776
# More vehicles than participants for crash  1851837
# More vehicles than participants for crash  1851849
# More vehicles than participants for crash  1851959
# More vehicles than participants for crash  1851966
# More vehicles than participants for crash  1852005
# More vehicles than participants for crash  1852048
# More vehicles than participants for crash  1852070
# More vehicles than participants for crash  1852116
# More vehicles than participants for crash  1852201
# More vehicles than participants for crash  1852212
# More vehicles than participants for crash  1852287
# More vehicles than participants for crash  1852369
# More vehicles than participants for crash  1852381
# More vehicles than participants for crash  1852385
# More vehicles than participants for crash  1852404
# More vehicles than participants for crash  1852464
# More vehicles than participants for crash  1852562
# More vehicles than participants for crash  1852623
# More vehicles than participants for crash  1852657
# More vehicles than participants for crash  1852735
# More vehicles than participants for crash  1852773
# More vehicles than participants for crash  1852807
# More vehicles than participants for crash  1852853
# More vehicles than participants for crash  1852933
# More vehicles than participants for crash  1852934
# More vehicles than participants for crash  1852937
# More vehicles than participants for crash  1852965
# More vehicles than participants for crash  1852981
# More vehicles than participants for crash  1853011
# More vehicles than participants for crash  1853019
# More vehicles than participants for crash  1853242
# More vehicles than participants for crash  1853265
# More vehicles than participants for crash  1853304
# More vehicles than participants for crash  1853339
# More vehicles than participants for crash  1853353
# More vehicles than participants for crash  1853448
# More vehicles than participants for crash  1853466
# More vehicles than participants for crash  1853499
# More vehicles than participants for crash  1853505
# More vehicles than participants for crash  1853517
# More vehicles than participants for crash  1853519
# More vehicles than participants for crash  1853543
# More vehicles than participants for crash  1853582
# More vehicles than participants for crash  1853699
# More vehicles than participants for crash  1853728
# More vehicles than participants for crash  1853788
# More vehicles than participants for crash  1853862
# More vehicles than participants for crash  1853863
# More vehicles than participants for crash  1853962
# More vehicles than participants for crash  1854013
# More vehicles than participants for crash  1854063
# More vehicles than participants for crash  1854066
# More vehicles than participants for crash  1854071
# More vehicles than participants for crash  1854092
# More vehicles than participants for crash  1854099
# More vehicles than participants for crash  1854169
# More vehicles than participants for crash  1854273
# More vehicles than participants for crash  1854309
# More vehicles than participants for crash  1854338
# More vehicles than participants for crash  1854339
# More vehicles than participants for crash  1854392
# More vehicles than participants for crash  1854398
# More vehicles than participants for crash  1855110
# More vehicles than participants for crash  1855657
# 303
# 2236

# %%
# statistical assertions
# Crash data is evenly distributed throughout the year
import matplotlib.pyplot as plt
df.plot.scatter(x='Crash Month', y='Crash Day')
# Out:
# <AxesSubplot:xlabel='Crash Month', ylabel='Crash Day'>

# %%
# statistical assertions
# Crashes are more during the middle of the day (office hours)
df = df[df['Crash Hour'] <= 24]
df.plot.scatter(x='Crash Hour', y='Crash Day')
# Out:
# <AxesSubplot:xlabel='Crash Hour', ylabel='Crash Day'>

# %%
crash_df = df[df['Record Type'] == 1]
vehicle_df = df[df['Record Type'] == 2]
participant_df = df[df['Record Type'] == 3]

crash_df.to_csv('crash_data.csv', index = False, header=True)
vehicle_df.to_csv('vehicle_data.csv', index = False, header=True)
participant_df.to_csv('participant_data.csv', index=False, header=True)
